# %% [markdown]
# <a href="https://colab.research.google.com/github/Dasari2708/lms-assignments/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# ...

# %%
pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import google.generativeai as genai
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
import PyPDF2
def extract_text_from_pdf(pdf_path):
  """Extracts text from a given health report PDF using PyPDF2."""
  text = ""
  with open(pdf_path, "rb") as file:
    reader = PyPDF2.PdfReader(file)
    for page in reader.pages:
      text += page.extract_text() + "\n"
  return text

# %%
def extract_health_insights(text):
  model = genai.GenerativeModel("gemini-1.5-flash")
  prompt = f"Extract key insights from the following health report: \n\n{text}"
  response = model.generate_content(prompt)
  return response.text
pdf_file = "health_report.pdf"
extracted_text = extract_text_from_pdf(pdf_file)
insights = extract_health_insights(extracted_text)
print("Key Insights: \n", insights)
# Out:
# Key Insights:
#  Key Insights from Mr. Kishan Goud's Health Report (MR2100003157):
#
# **Infectious Diseases:**
#
# * **Negative for Dengue:**  Tests for Dengue NS1 antigen, IgG, and IgM were all negative.
# * **Negative for Malaria:** Rapid Malaria tests (P.V and P.F) were negative.
# * **Possible Typhoid Exposure (Requires Clinical Correlation):**  Widal test showed elevated titers for *Salmonella Typhi* "O" (1:160) and "H" (1:80).  While above the reference range (1:20), this alone isn't definitive for active typhoid.  Further clinical evaluation is necessary.  Paratyphoid A and B titers were within the reference range.
#
# **Hematology:**
#
# * **Complete Blood Count (CBC) mostly within normal limits:**  Hemoglobin, RBC, WBC, platelet count, and PCV are mostly within the normal ranges.  Differential count shows a slightly elevated lymphocyte count (31%), but still within the normal range.
# ...

# %%
def summarize_health_report(text):
    """Summarizes the health report using Gemini AI."""
    model = genai.GenerativeModel("gemini-1.5-flash")
    prompt = f"Summarize the following health report:\n\n{text}"
    response = model.generate_content(prompt)
    return response.text

summary = summarize_health_report(extracted_text)
print("Summary:\n", summary)
# Out:
# Summary:
#  This is a comprehensive health report for Mr. Kishan Goud (MR2100003157) dated 01/02/2021.  The report includes the following:
#
# **Infectious Disease Tests:**
#
# * **Widal Test:** Elevated titers for *Salmonella Typhi* "O" (1:160) and "H" (1:80), suggesting possible past or current typhoid fever.  *Salmonella Paratyphi* "AH" and "BH" titers were within the normal range.
# * **Dengue Serology:** Negative for Dengue NS1 antigen, IgG, and IgM, ruling out a recent dengue infection.
# * **Rapid Malaria Test:** Negative for both *Plasmodium falciparum* and *Plasmodium vivax*.
#
# **Hematology:**
#
# * **Complete Blood Picture (CBC):**  Hemoglobin, RBC, WBC, and platelet counts were all within normal ranges. Differential count also showed normal percentages of neutrophils, lymphocytes, eosinophils, monocytes, and basophils.  Peripheral blood smear showed normal RBC morphology and WBCs within normal limits.
# ...

# %%
def detect_abnormalities(text):
    model = genai.GenerativeModel("gemini-1.5-flash")
    prompt = f"Analyze the lab test results and highlight any abnoraml values: \n\n{text}"
    response = model.generate_content(prompt)
    return response.text
abnormalities = detect_abnormalities(extracted_text)
print("Potential Abnormalities: \n", abnormalities)
# Out:
# Potential Abnormalities:
#  The following lab results for Mr. Kishan Goud are outside the reference ranges:
#
# * **Widal Test:**  S. Typhi "O" (1:160) and S. Typhi "H" (1:80) are significantly elevated above the reference range of 1:20. This suggests a possible past or present infection with *Salmonella Typhi*.  The titers are high enough to be suggestive of infection but further clinical context is needed for definitive diagnosis.
#
# * **ESR (Erythrocyte Sedimentation Rate):** Both the 1st hour (26 mm/hr) and 2nd hour (52 mm/hr) values are significantly elevated above the normal range (0-8 mm/hr for the 1st hour).  This indicates inflammation or infection somewhere in the body.
#
# * **Serum Sodium:**  The serum sodium level (122 mmol/l) is below the reference range (135-146 mmol/l), indicating hyponatremia (low sodium).  This requires further investigation to determine the underlying cause.
#
# ...

# %%
def explain_medical_terms(text):
    """Asks Gemini AI to simplify medical terms for patient understanding."""
    model = genai.GenerativeModel("gemini-1.5-flash")
    prompt = f"Translate the medical terms in the following health report into simple language:\n\n{text}"
    response = model.generate_content(prompt)
    return response.text

explanation = explain_medical_terms(extracted_text)
print("Simplified Explanation:\n", explanation)
# Out:
# Simplified Explanation:
#  This report shows the results of several blood tests for Mr. Kishan Goud. Here's a simplified explanation:
#
# **1. Widal Test (for Typhoid):**  This test checks for antibodies to typhoid fever.  The results show:
#
# * **S. Typhi "O" 1:160:**  A moderately elevated level, suggesting possible past or current typhoid infection.  Higher numbers generally suggest a more recent or active infection.
# * **S. Typhi "H" 1:80:**  A moderately elevated level, similarly suggesting possible past or current typhoid infection.
# * **S. Paratyphi "AH" 1:20:** Within the normal range, indicating no evidence of this type of paratyphoid infection.
# * **S. Paratyphi "BH" 1:20:** Within the normal range, indicating no evidence of this type of paratyphoid infection.
#
#
# **2. Dengue Serology:** This test checks for dengue fever.  All results (NS1 antigen, IgG, and IgM) are negative, meaning no evidence of current or recent dengue infection.
#
#
# ...
